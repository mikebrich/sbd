# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("MarginAnalysis.xlsx", sheet_name="Final Analysis")
df = df.iloc[:, 0:5]

df
# Out:
#                                         Pool / Client  Direct Labor Cost  \
# 0                          Basking Ridge Country Club       47309.290397
# 1                                        Bedens Brook       65209.337575
# 2                                       Bernardsville       68928.494872
# 3                             Cedar Hill Country Club       30323.483297
# 4                            Cedarbrook at Branchburg        7353.691306
# 5                          Cherry Valley Country Club       60468.718213
# 6                            City Homes at Essex Park        6716.756909
# 7                                   Claridge House #1       20101.475562
# 8                                Colonia Country club       15706.463614
# 9                            Essex Fells Country Club       55593.394699
# 10                             Fairways at Livingston       11292.556156
# 11  Flemington South Estates - Wellington & Yorkshire       19628.300977
# 12           Grand at River Dale - Lower & Upper Pool       35474.984697
# 13                              Hawk pointe golf club        6778.774957
# 14                                 hearthwood village        9917.685574
# 15                         Hills Village north master       22808.430873
# 16                                    Huntington Park       13479.050652
# 17                                       Kellogg Club       33322.437094
# 18                                         Kimberwyck       12784.979769
# 19                                    Madison commons        8854.238066
# 20                             Maplewood Country Club       52441.205804
# 21                        orange lawn and tennis club       34249.573542
# 22                             Pointe at crystal lake        8130.392327
# 23                        residences at columbia park        9233.454707
# 24                                 Roundtop Swim Club       29667.935376
# 25                           Shackamaxon Country Club       45121.429619
# 26                         society hill at Branchburg        6599.476599
# 27                                    Spring Brook CC       83110.816958
# 28                         Stanton Ridge Country Club       17262.747134
# 29                               The nell at Dunellen       10337.400417
# 30                                   Trump Bedminster       49395.324422
# 31                                          Woodlands        9570.939390
#
#     June & July Rev    Margin ($)  Margin (%)
# 0             75000  27690.709603    0.369209
# 1             81750  16540.662425    0.202332
# 2            113750  44821.505128    0.394035
# 3             42250  11926.516703    0.282284
# 4             21000  13646.308694    0.649824
# 5             67500   7031.281787    0.104167
# 6             21250  14533.243091    0.683917
# 7             39250  19148.524438    0.487860
# 8             35900  20193.536386    0.562494
# 9             77000  21406.605301    0.278008
# 10            28250  16957.443844    0.600263
# 11            45250  25621.699023    0.566225
# 12            55000  19525.015303    0.355000
# 13            24000  17221.225043    0.717551
# 14            32450  22532.314426    0.694370
# 15            59000  36191.569127    0.613416
# 16            34000  20520.949348    0.603557
# 17            52000  18677.562906    0.359184
# 18            29000  16215.020231    0.559139
# 19            34100  25245.761934    0.740345
# 20            58500   6058.794196    0.103569
# 21            64000  29750.426458    0.464850
# 22            27250  19119.607673    0.701637
# 23            28250  19016.545293    0.673152
# 24            49000  19332.064624    0.394532
# 25            89250  44128.570381    0.494438
# 26            26500  19900.523401    0.750963
# 27            66250 -16860.816958   -0.254503
# 28            41000  23737.252866    0.578957
# 29            34000  23662.599583    0.695959
# 30            74750  25354.675578    0.339193
# 31            27250  17679.060610    0.648773

# %%
# Sort by Margin % descending
df_sorted = df.sort_values(by="Margin (%)", ascending=False)

# Normalize values for colormap
norm = plt.Normalize(df_sorted["Margin (%)"].min(), df_sorted["Margin (%)"].max())

# Green → White → Red colormap
cmap = mcolors.LinearSegmentedColormap.from_list("green_white_red", ["red", "white", "green"])

# Map colors to margins
colors = cmap(norm(df_sorted["Margin (%)"]))

# Create the plot
plt.figure(figsize=(10, 8))
plt.barh(df_sorted["Pool / Client"], df_sorted["Margin (%)"], color=colors)
plt.xlabel("Margin %")
plt.title("Pools Sorted by Margin % (Descending) - Green to Red Gradient")
plt.gca().invert_yaxis()

# Format x-axis as percentage
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda x, _: f'{x:.0%}'))

plt.tight_layout()
plt.show()

# %%
# Bubble size = absolute margin ($), scaled
sizes = (df["Margin ($)"].abs() / df["Margin ($)"].abs().max()) * 2000

# Bubble color = red → white → green by margin ($)
norm = plt.Normalize(df["Margin ($)"].min(), df["Margin ($)"].max())
cmap = mcolors.LinearSegmentedColormap.from_list("red_white_green", ["red", "white", "green"])
colors = cmap(norm(df["Margin ($)"]))

# ---- Plot ----
x = df["June & July Rev"]
y = df["Margin (%)"]

plt.figure(figsize=(10, 7))
plt.scatter(x, y, s=sizes, c=colors, edgecolors="k", alpha=0.6, marker="o")

# Trendline to show relationship
coeffs = np.polyfit(x, y, 1)
trend_x = np.linspace(x.min(), x.max(), 100)
trend_y = coeffs[0] * trend_x + coeffs[1]
plt.plot(trend_x, trend_y, linewidth=2)

# Formatting
plt.title("Revenue vs. Margin % (Bubble size & color = Margin $)")
plt.xlabel("June & July Revenue ($)")
plt.ylabel("Margin %")
plt.gca().yaxis.set_major_formatter(plt.FuncFormatter(lambda v, _: f"{v:.0%}"))
plt.gca().xaxis.set_major_formatter(plt.FuncFormatter(lambda v, _: f"${v:,.0f}"))
plt.tight_layout()
plt.show()
