# %% [markdown]
# ### Imports

# %%
import pandas as pd
import numpy as np
import json
import requests
from datetime import datetime
import copy
import heapq

# %% [markdown]
# ### Load Input DFs

# %%
production_matrix = pd.read_excel("SBD2.xlsx", sheet_name="ProductionMatrix", header=1)
production_matrix = production_matrix.drop(['(blank)','Grand Total'], axis=1)
production_matrix = production_matrix.iloc[:-2]

# %%
production_matrix
# Out:
#                   Row Labels  Allentown  Charlotte    Chicago     Dallas  \
# 0             Aerosol Bottle        NaN        NaN        NaN        NaN
# 1                Aerosol Can        NaN    34146.0   453323.0   887734.0
# 2            Bottle with Cap   687366.0   262349.0        NaN        NaN
# 3           Bottle with Logo        NaN        NaN        NaN        NaN
# 4             Branded Bottle        NaN        NaN        NaN        NaN
# ..                       ...        ...        ...        ...        ...
# 110  Vacuum-Insulated Bottle   565413.0   122624.0  1525662.0  1132476.0
# 111        Wide-Mouth Bottle   440054.0        NaN        NaN        NaN
# 112           Wide-Mouth Can        NaN   364832.0   818753.0        NaN
# 113          Windowed Bottle   200687.0        NaN        NaN        NaN
# 114             Windowed Can        NaN   121067.0   873011.0   862994.0
#
#       Fontana  Nashville  Portland    Tucson
# 0         NaN   620932.0       NaN  213742.0
# 1    586080.0        NaN  280893.0       NaN
# 2    324161.0        NaN   75844.0       NaN
# 3         NaN        NaN       NaN  254629.0
# 4         NaN        NaN       NaN  129325.0
# ..        ...        ...       ...       ...
# 110       NaN  1130398.0  175563.0       NaN
# 111       NaN   172508.0       NaN       NaN
# 112  673321.0        NaN   71299.0       NaN
# 113       NaN        NaN       NaN  247746.0
# 114  292403.0        NaN       NaN       NaN
#
# [115 rows x 9 columns]

# %%
margin_matrix = pd.read_excel("SBD2.xlsx", sheet_name="MarginMatrix", header=1)
margin_matrix = margin_matrix.drop(['(blank)','Grand Total'], axis=1)
margin_matrix = margin_matrix.iloc[:-2]

# %%
margin_matrix
# Out:
#                   Row Labels  Allentown  Charlotte   Chicago    Dallas  \
# 0             Aerosol Bottle        NaN        NaN       NaN       NaN
# 1                Aerosol Can        NaN   0.248429  0.500158  0.172298
# 2            Bottle with Cap   0.267870   0.312923       NaN       NaN
# 3           Bottle with Logo        NaN        NaN       NaN       NaN
# 4             Branded Bottle        NaN        NaN       NaN       NaN
# ..                       ...        ...        ...       ...       ...
# 110  Vacuum-Insulated Bottle   0.102838   0.186494  0.957254  1.100048
# 111        Wide-Mouth Bottle   0.324883        NaN       NaN       NaN
# 112           Wide-Mouth Can        NaN   0.875111  0.713066       NaN
# 113          Windowed Bottle   0.369882        NaN       NaN       NaN
# 114             Windowed Can        NaN   0.332412  0.375030  0.605804
#
#       Fontana  Nashville  Portland    Tucson
# 0         NaN   0.417144       NaN  0.229868
# 1    0.464887        NaN  0.293694       NaN
# 2    0.292407        NaN  0.187039       NaN
# 3         NaN        NaN       NaN  0.409059
# 4         NaN        NaN       NaN  0.461297
# ..        ...        ...       ...       ...
# 110       NaN   0.177778  0.403307       NaN
# 111       NaN   0.198844       NaN       NaN
# 112  0.660749        NaN  0.260806       NaN
# 113       NaN        NaN       NaN  0.315296
# 114  0.563303        NaN       NaN       NaN
#
# [115 rows x 9 columns]

# %%
city_cap_matrix = pd.read_excel("SBD2.xlsx", sheet_name="CityCapacity")
city_cap_matrix = city_cap_matrix.rename(columns={"Unnamed: 0": "Capacity Metric"})

city_cap_matrix
# Out:
#     Capacity Metric  Allentown  Charlotte   Chicago    Dallas   Fontana  \
# 0  Current Capacity   12500016   10000042  30000034  45000042  24000044
# 1      Max Capacity   25000000   20000000  50000000  60000000  30000000
# 2             Slack   12499984    9999958  19999966  14999958   5999956
#
#    Nashville  Portland    Tucson
# 0   31500020  13500042   6000021
# 1   45000000  15000000  10000000
# 2   13499980   1499958   3999979

# %%
results_allocation_matrix = production_matrix.copy()
value_cols = results_allocation_matrix.columns.drop("Row Labels") # everything except row labels
results_allocation_matrix[value_cols] = np.nan #blank out values
results_allocation_matrix
# Out:
#                   Row Labels  Allentown  Charlotte  Chicago  Dallas  Fontana  \
# 0             Aerosol Bottle        NaN        NaN      NaN     NaN      NaN
# 1                Aerosol Can        NaN        NaN      NaN     NaN      NaN
# 2            Bottle with Cap        NaN        NaN      NaN     NaN      NaN
# 3           Bottle with Logo        NaN        NaN      NaN     NaN      NaN
# 4             Branded Bottle        NaN        NaN      NaN     NaN      NaN
# ..                       ...        ...        ...      ...     ...      ...
# 110  Vacuum-Insulated Bottle        NaN        NaN      NaN     NaN      NaN
# 111        Wide-Mouth Bottle        NaN        NaN      NaN     NaN      NaN
# 112           Wide-Mouth Can        NaN        NaN      NaN     NaN      NaN
# 113          Windowed Bottle        NaN        NaN      NaN     NaN      NaN
# 114             Windowed Can        NaN        NaN      NaN     NaN      NaN
#
#      Nashville  Portland  Tucson
# 0          NaN       NaN     NaN
# 1          NaN       NaN     NaN
# 2          NaN       NaN     NaN
# 3          NaN       NaN     NaN
# 4          NaN       NaN     NaN
# ..         ...       ...     ...
# 110        NaN       NaN     NaN
# 111        NaN       NaN     NaN
# 112        NaN       NaN     NaN
# 113        NaN       NaN     NaN
# 114        NaN       NaN     NaN
#
# [115 rows x 9 columns]

# %% [markdown]
# ## Find a Good Allocation of Production for a Certain Shutdown Candidate

# %%
margin_matrix_test = margin_matrix.copy()

# %%
shutdown_city = "Chicago"

# %% [markdown]
# ### 3rd Try: Extrapolating to finding all next best cities

# %%
for product in margin_matrix_test["Row Labels"]:

    #How much production we need to move
    production = production_matrix.loc[production_matrix["Row Labels"] == product, shutdown_city].values[0]
    
    #Find the best available receiver city
    n = 1
    while True:
        try:
            #Find nth best receiver city (excludes shutdown city internally)
            best_receiver = nthBestReceiverCity(margin_matrix_test, shutdown_city, product, n)

            #Find Receiver cities current slack (production capacity left)
            receiverCitySlack = city_cap_matrix.loc[city_cap_matrix['Capacity Metric'] == 'Slack', best_receiver].values[0]
 
            if receiverCitySlack > production:

                #Then can allocate that products production into the best reciever city
                results_allocation_matrix.loc[results_allocation_matrix["Row Labels"] == product, best_receiver] = production
        
                #And update the receiver city slack
                city_cap_matrix.loc[city_cap_matrix["Capacity Metric"] == "Slack", best_receiver] = receiverCitySlack - production

                break #successful allocation so move onto next product

        
            else: #Else, not enough slack 
                #Try the next best receiver city
                n += 1
                
        except IndexError: #If you can't find a viable receiver
            #print("No viable receiver city found")
            print(f"No viable receiver city found for '{product}' after trying {n - 1} options")
            break
# Out:
# No viable receiver city found for 'Aerosol Bottle' after trying 2 options
# No viable receiver city found for 'Bottle with Cap' after trying 4 options
# No viable receiver city found for 'Bottle with Logo' after trying 1 options
# No viable receiver city found for 'Branded Bottle' after trying 1 options
# No viable receiver city found for 'Can with Logo' after trying 3 options
# No viable receiver city found for 'Classic Bottle' after trying 2 options
# No viable receiver city found for 'Classic Can' after trying 3 options
# No viable receiver city found for 'Compact Bottle' after trying 2 options
# No viable receiver city found for 'Customized Bottle' after trying 1 options
# No viable receiver city found for 'Customized Can' after trying 2 options
# No viable receiver city found for 'Dropper Cap Bottle' after trying 3 options
# No viable receiver city found for 'Durable Bottle' after trying 2 options
# No viable receiver city found for 'Easy-Grip Bottle' after trying 2 options
# No viable receiver city found for 'Easy-Open Bottle' after trying 2 options
# No viable receiver city found for 'Eco-Friendly Bottle' after trying 1 options
# No viable receiver city found for 'Eco-Friendly Can' after trying 2 options
# No viable receiver city found for 'Embossed Bottle' after trying 2 options
# No viable receiver city found for 'Embossed Can' after trying 4 options
# No viable receiver city found for 'Flip Cap Bottle' after trying 3 options
# No viable receiver city found for 'Flip-Cap Bottle' after trying 4 options
# No viable receiver city found for 'Holographic Bottle' after trying 2 options
# No viable receiver city found for 'Holographic Can' after trying 4 options
# No viable receiver city found for 'Impact-Resistant Bottle' after trying 2 options
# No viable receiver city found for 'Impact-Resistant Can' after trying 3 options
# No viable receiver city found for 'Insulated Bottle' after trying 2 options
# No viable receiver city found for 'Large Bottle' after trying 2 options
# No viable receiver city found for 'Large Capacity Bottle' after trying 1 options
# No viable receiver city found for 'Limited Edition Bottle' after trying 1 options
# No viable receiver city found for 'Limited Edition Can' after trying 4 options
# No viable receiver city found for 'Logo Bottle' after trying 1 options
# No viable receiver city found for 'Matte Bottle' after trying 1 options
# No viable receiver city found for 'Matte Can' after trying 3 options
# No viable receiver city found for 'Novelty Bottle' after trying 4 options
# No viable receiver city found for 'Peelable Bottle' after trying 2 options
# No viable receiver city found for 'Pop-Top Bottle' after trying 2 options
# No viable receiver city found for 'Premium Bottle' after trying 1 options
# No viable receiver city found for 'Pull Tab Bottle' after trying 1 options
# No viable receiver city found for 'Pull-Tab Bottle' after trying 1 options
# No viable receiver city found for 'Pull-Tab Can' after trying 1 options
# No viable receiver city found for 'Push-Up Bottle' after trying 2 options
# No viable receiver city found for 'Resealable Bottle' after trying 2 options
# No viable receiver city found for 'Resealable Tab Bottle' after trying 1 options
# No viable receiver city found for 'Resealable Tab Can' after trying 3 options
# No viable receiver city found for 'Shatterproof Bottle' after trying 1 options
# No viable receiver city found for 'Sleek Bottle' after trying 2 options
# No viable receiver city found for 'Slim Bottle' after trying 1 options
# No viable receiver city found for 'Slim Can' after trying 3 options
# No viable receiver city found for 'Sports Bottle' after trying 3 options
# No viable receiver city found for 'Squeeze Bottle' after trying 3 options
# No viable receiver city found for 'Standard Bottle' after trying 2 options
# No viable receiver city found for 'Standard Size Bottle' after trying 1 options
# No viable receiver city found for 'Standard Size Can' after trying 2 options
# No viable receiver city found for 'Straw Bottle' after trying 3 options
# No viable receiver city found for 'Tall Bottle' after trying 2 options
# No viable receiver city found for 'Tallboy Bottle' after trying 3 options
# No viable receiver city found for 'Tallboy Size Bottle' after trying 1 options
# No viable receiver city found for 'Tallboy Size Can' after trying 2 options
# No viable receiver city found for 'Tamper-Evident Bottle' after trying 5 options
# No viable receiver city found for 'Tear-Strip Bottle' after trying 4 options
# No viable receiver city found for 'Textured Bottle' after trying 1 options
# No viable receiver city found for 'Traditional Bottle' after trying 1 options
# No viable receiver city found for 'Twist Cap Bottle' after trying 1 options
# No viable receiver city found for 'Twist Nozzle Bottle' after trying 3 options
# No viable receiver city found for 'Twist-Lock Bottle' after trying 1 options
# No viable receiver city found for 'Twist-Up Bottle' after trying 2 options
# No viable receiver city found for 'Twist-Up Can' after trying 3 options
# No viable receiver city found for 'Unbreakable Bottle' after trying 1 options
# No viable receiver city found for 'Unbreakable Can' after trying 4 options
# No viable receiver city found for 'Wide-Mouth Bottle' after trying 2 options
# No viable receiver city found for 'Windowed Bottle' after trying 2 options

# %%
results_allocation_matrix
# Out:
#                   Row Labels  Allentown  Charlotte  Chicago     Dallas  \
# 0             Aerosol Bottle        NaN        NaN      NaN        NaN
# 1                Aerosol Can        NaN        NaN      NaN        NaN
# 2            Bottle with Cap        NaN        NaN      NaN        NaN
# 3           Bottle with Logo        NaN        NaN      NaN        NaN
# 4             Branded Bottle        NaN        NaN      NaN        NaN
# ..                       ...        ...        ...      ...        ...
# 110  Vacuum-Insulated Bottle        NaN        NaN      NaN  1525662.0
# 111        Wide-Mouth Bottle        NaN        NaN      NaN        NaN
# 112           Wide-Mouth Can        NaN   818753.0      NaN        NaN
# 113          Windowed Bottle        NaN        NaN      NaN        NaN
# 114             Windowed Can        NaN        NaN      NaN   873011.0
#
#       Fontana  Nashville  Portland  Tucson
# 0         NaN        NaN       NaN     NaN
# 1    453323.0        NaN       NaN     NaN
# 2         NaN        NaN       NaN     NaN
# 3         NaN        NaN       NaN     NaN
# 4         NaN        NaN       NaN     NaN
# ..        ...        ...       ...     ...
# 110       NaN        NaN       NaN     NaN
# 111       NaN        NaN       NaN     NaN
# 112       NaN        NaN       NaN     NaN
# 113       NaN        NaN       NaN     NaN
# 114       NaN        NaN       NaN     NaN
#
# [115 rows x 9 columns]

# %%
city_cap_matrix
# Out:
#     Capacity Metric  Allentown  Charlotte   Chicago    Dallas   Fontana  \
# 0  Current Capacity   12500016   10000042  30000034  45000042  24000044
# 1      Max Capacity   25000000   20000000  50000000  60000000  30000000
# 2             Slack   12499984    1382505  19999966   5604007    169382
#
#    Nashville  Portland    Tucson
# 0   31500020  13500042   6000021
# 1   45000000  15000000  10000000
# 2   11421764    276438   2098481

# %%
total_slack = city_cap_matrix.loc[city_cap_matrix["Capacity Metric"] == "Slack"].iloc[:, 1:].sum(axis=1).values[0]
total_slack
# Out:
# 53452527

# %% [markdown]
# ### Second Try: If the Slack can't take on the production, it will just not put it in (so missing allocation)

# %%
for product in margin_matrix_test["Row Labels"]:

    #Find the best available receiver city
    best_receiver = nthBestReceiverCity(margin_matrix_test, shutdown_city, product, 1)

    #How much production we need to move
    production = production_matrix.loc[production_matrix["Row Labels"] == product, shutdown_city].values[0]

    #Receiver cities current slack (production capacity left)
    receiverCitySlack = city_cap_matrix.loc[city_cap_matrix['Capacity Metric'] == 'Slack', best_receiver].values[0]
 
    if receiverCitySlack > production:

        #Then can pull that products production into that reciever city
        results_allocation_matrix.loc[results_allocation_matrix["Row Labels"] == product, best_receiver] = production
        
        #And update the receiver city slack
        city_cap_matrix.loc[city_cap_matrix["Capacity Metric"] == "Slack", best_receiver] = receiverCitySlack - production


   #else:
        #Find next best receiver

# %%
results_allocation_matrix

# %%
city_cap_matrix

# %% [markdown]
# ### First Try: This Works Like the Excel Currently

# %%
shutdown_city = "Charlotte"

for product in margin_matrix_test["Row Labels"]:

    #Find the best available receiver city
    best_receiver = nthBestReceiverCity(margin_matrix_test, shutdown_city, product, 1)

    #How much production we need to move
    production = production_matrix.loc[production_matrix["Row Labels"] == product, shutdown_city].values[0]

    #Receiver cities current slack (production capacity left)

    ##### This is actually finding the shut down cities slack (forcing the if to never fail)
    receiverCitySlack = city_cap_matrix.loc[city_cap_matrix['Capacity Metric'] == 'Slack', shutdown_city].values[0]
 
    if receiverCitySlack > production:

        #Then can pull that products production into that reciever city
        results_allocation_matrix.loc[results_allocation_matrix["Row Labels"] == product, best_receiver] = production
        
        #And update the receiver city slack
        city_cap_matrix.loc[city_cap_matrix["Capacity Metric"] == "Slack", best_receiver] -= production


   #else:
        #Find next best receiver

# %%
results_allocation_matrix

# %%
city_cap_matrix

# %% [markdown]
# ### Function to Find nth Best Receiver (Given Single Product)

# %%
## Function to Find the nth best Receiver 
#Input: MarginMatrix, ShutdownCity, Portfolio (Product), n (the nth best city you want)
#Output: the name of the nth best receiver city that is not the shutdown city

# %%
def nthBestReceiverCity(margin_df, shutdown_city, product, n):

    nth_city = ""

    #Drop the shutdown city from the margin matrix
    margin_df_drop = margin_df.drop(columns=[shutdown_city])

    #Isolate the product row
    product_row = margin_df_drop[margin_df_drop["Row Labels"] == product]

    #Build a list of the non NaN CM values
    numeric_row = product_row.select_dtypes(include='number').iloc[0]
    cleaned_row = numeric_row.dropna() #drop NaNs

    if n > len(cleaned_row):
        raise IndexError("Not enough cities to satisfy nth best request")

    #Find the nth Largest CM value
    nth_largest_val = np.partition(cleaned_row.values, -n)[-n]

    #Find the nth Largest city
    nth_city = cleaned_row[cleaned_row == nth_largest_val].index[0]

    return nth_city

# %%
shut_c = "Portland"

mm_no_portland = margin_matrix.drop(columns=[shut_c])
mm_no_portland

# %%
prod = "Aerosol Bottle"

aerosol_row = mm_no_portland[mm_no_portland["Row Labels"] == prod]
aerosol_row

# %%
numeric_row = aerosol_row.select_dtypes(include='number').iloc[0]
cleaned_row = numeric_row.dropna() #Drop NaNs
n = 2
nth_largest_val = np.partition(cleaned_row.values, -n)[-n] #Get nth largest value
nth_largest_val

# %%
nth_city = cleaned_row[cleaned_row == nth_largest_val].index[0]
nth_city
